# %%
# Per importare la libreria che si trova nella cartella "Lib_Gamma" (che è due sottocartelle sopra quella attuale)

import sys
import os

# '../..' significa "sali di due cartelle", poi '/Librerie' ti fa entrare lì dentro
percorso_librerie = os.path.abspath('../../Lib_Gamma')

# Aggiungiamo il percorso corretto
sys.path.append(percorso_librerie)

# %%
# IMPORT LIBRERIA
# # Per tenere sempre la libreria aggiornata (si può fare SOLO in un notebook!):
# %load_ext autoreload
# %autoreload 2

import libreria_Model_Tournament as lmt

# %%
import numpy as np

# Inizializza le liste (da eseguire una sola volta)
v_bias_list = []

# Liste per il primo picco (es. 511 keV)
fwhm_p1_list, err_fwhm_p1_list = [], []
centro_p1_list, err_centro_p1_list = [], []
fwhm_rel_p1_list, err_fwhm_rel_p1_list = [], []

# Liste per il secondo picco (es. 1274 keV)
fwhm_p2_list, err_fwhm_p2_list = [], []
centro_p2_list, err_centro_p2_list = [], []
fwhm_rel_p2_list, err_fwhm_rel_p2_list = [], []
